# %% [markdown]
# # This is a Notebook to run RNAseq analysis server
# # For FFPE or frozen samples
#
#
# This is a warp up of the few steps for the pre-procesing in the RNAseq analaysis, the notebook include:
# - fastqc
# - trimming, trim-galore
# - Alignment, STAR
# - Annotation counts, featureCounts
# - multiqc, QC of the process

# %%
#this is in case you forget where you are and what is in it
# !pwd
#!ls
# Out:
# /DATA/home/l.gonzalez/Notebooks

# %%
import os, sys
import glob
import logging

# %% [markdown]
# ### Before starting the analysis we will check the QC of the fastq files usign fastqc
# To do that, please go to the cell below and change the path to the folder where the fastq files are, then run it

# %%
# !fastqc /DATA/share/pipelines/lgleon/test/testCode_steps_Nousefuldata/testdata/fastq/*fastq.gz

# %% [markdown]
# ## Run trim_galore for the trimming part paired-end
# Then remove the adaptors using trim galore (conda)
# The CLI can be run directly

# %%
#!conda init bash

# %%
#Trimming step go where the fastq raw files are

#Binary = "/home/l.gonzalez/programs/TrimGalore-0.6.5/trim_galore"
#Be aware that the path to the raw files (prj) is hard coded
# Change it  !!!!!!!!!!!!
#prj is hardcode, need to be change with any new analysis

#Script, DO NOT RUN !!!!!!!!!!!!!!!!!
#!bin/bash

#############################################################################
##############################################################################
# SINGLE-END part
##############################################################################
##############################################################################

##careful with fastq.gz OR fq.gz   can give problems!

##Hardcode fastq folder change when need it
#    prj=/DATA/share/pipelines/lgleon/C5_RNAseq_FFPE/fastq_files/

#for i in ${prj}/*R1*.f*q.gz 

#do 
#    name=$(basename ${i} _R1_001.fastq.gz)

#	echo ${name}
#	echo ${name}_R1_001.fastq.gz
#	echo ${name}_R2_001.fastq.gz
#	echo ${prj}trimmed/


#    /home/l.gonzalez/programs/TrimGalore-0.6.5/trim_galore -q 35 -o ${prj}trimmed/ ${name}_R1_001.fastq.gz
    

#done

#############################################################################
##############################################################################
# PAIRED-END part
##############################################################################
##############################################################################
#to work with this part remove the # in the single ones, doubles are explanations

##careful with fastq.gz OR fq.gz   can give problems!

##Hardcode fastq folder change when need it
        prj=/DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals

for i in ${prj}/*R1*.f*q 

do 
    #name=$(basename ${i} _R1_001.fastq.gz)
    name=$(basename ${i/%_R1_001.f*q})

	echo ${name}
    #echo ${name/%_R1_001.f*q}       #filenamestem=${file/%.f*q.gz/}
	echo ${name}_R1_001.fastq  #option namefq1=${name}_R1_001.fastq.gz, then in the cli use ${namefq1}
	echo ${name}_R2_001.fastq  #option namefq2=${name}_R2_001.fastq.gz
    echo ${prj}/${name}_R1_001.fastq
    echo ${prj}/trimmNormals/          #option pathoutput=${prj}/trimmed/



    /home/l.gonzalez/programs/TrimGalore-0.6.5/trim_galore -q 35 --paired -o ${prj}/trimmNormals/ ${prj}/${name}_R1_001.fastq ${prj}/${name}_R2_001.fastq #> logtrim.txt &
    
    
    #### If you run this from Notebook, to the other folder then ${name} is not enough, that is only the name os the files
    ####you need to put ${prj}/${name}_R1_001.fastq.gz to work ??
    


done

# %%
#once you change the prj folder, run this cell
#!bash /<path>/testrun_trimgalorePaired_notebook.sh

# !bash /home/l.gonzalez/Notebooks/testrun_trimgalorePaired_notebook.sh
# Out:
# CC15N_CAGATC_L007
# CC15N_CAGATC_L007_R1_001.fastq
# CC15N_CAGATC_L007_R2_001.fastq
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R1_001.fastq
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 3.4
# single-core operation.
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R1_001.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	102403	AGATCGGAAGAGC	1000000	10.24
# Nextera	34	CTGTCTCTTATA	1000000	0.00
# smallRNA	8	TGGAATTCTCGG	1000000	0.00
# Using Illumina adapter for trimming (count: 102403). Second best hit was Nextera (count: 34)
#
# Writing report to '/DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/CC15N_CAGATC_L007_R1_001.fastq_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R1_001.fastq
# Trimming mode: paired-end
# Trim Galore version: 0.6.4_dev
# Cutadapt version: 3.4
# Number of cores used for trimming: 1
# Quality Phred score cutoff: 35
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length for both reads before a sequence pair gets removed: 20 bp
#
# Cutadapt seems to be fairly up-to-date (version 3.4). Setting -j 1
# Writing final adapter and quality trimmed output to CC15N_CAGATC_L007_R1_001_trimmed.fq
#
#
#   >>> Now performing quality (cutoff '-q 35') and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R1_001.fastq <<<
# 10000000 sequences processed
# 20000000 sequences processed
# 30000000 sequences processed
# 40000000 sequences processed
# This is cutadapt 3.4 with Python 3.8.5
# Command line parameters: -j 1 -e 0.1 -q 35 -O 1 -a AGATCGGAAGAGC /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R1_001.fastq
# Processing reads on 1 core in single-end mode ...
# Finished in 338.99 s (8 µs/read; 7.38 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              41,714,643
# Reads with adapters:                14,577,907 (34.9%)
# Reads written (passing filters):    41,714,643 (100.0%)
#
# Total basepairs processed: 5,256,045,018 bp
# Quality-trimmed:           1,344,605,927 bp (25.6%)
# Total written (filtered):  3,804,862,636 bp (72.4%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 14577907 times
#
# No. of allowed errors:
# 1-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
#   A: 27.7%
#   C: 29.7%
#   G: 25.4%
#   T: 17.2%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	6665667	10428660.8	0	6665667
# 2	2341388	2607165.2	0	2341388
# 3	679999	651791.3	0	679999
# 4	312790	162947.8	0	312790
# 5	198896	40737.0	0	198896
# 6	240818	10184.2	0	240818
# 7	231241	2546.1	0	231241
# 8	167305	636.5	0	167305
# 9	215412	159.1	0	214983 429
# 10	137318	39.8	1	135911 1407
# 11	130973	9.9	1	129479 1494
# 12	166385	2.5	1	164630 1755
# 13	150746	0.6	1	148918 1828
# 14	166520	0.6	1	164244 2276
# 15	145140	0.6	1	142941 2199
# 16	148321	0.6	1	145959 2362
# 17	182608	0.6	1	180010 2598
# 18	123336	0.6	1	121697 1639
# 19	127970	0.6	1	126151 1819
# 20	114520	0.6	1	112813 1707
# 21	156562	0.6	1	154199 2363
# 22	115566	0.6	1	113835 1731
# 23	115088	0.6	1	113312 1776
# 24	126789	0.6	1	124721 2068
# 25	107910	0.6	1	106347 1563
# 26	82573	0.6	1	81338 1235
# 27	101786	0.6	1	100177 1609
# 28	106395	0.6	1	104706 1689
# 29	83445	0.6	1	82152 1293
# 30	82253	0.6	1	81061 1192
# 31	68822	0.6	1	67779 1043
# 32	77576	0.6	1	76430 1146
# 33	49794	0.6	1	48844 950
# 34	71962	0.6	1	70776 1186
# 35	67889	0.6	1	66794 1095
# 36	58054	0.6	1	57170 884
# 37	48649	0.6	1	47948 701
# 38	48742	0.6	1	47993 749
# 39	33939	0.6	1	33384 555
# 40	37941	0.6	1	37007 934
# 41	88665	0.6	1	87961 704
# 42	5694	0.6	1	5584 110
# 43	3180	0.6	1	3100 80
# 44	5202	0.6	1	5122 80
# 45	13225	0.6	1	13079 146
# 46	13791	0.6	1	13602 189
# 47	17188	0.6	1	16972 216
# 48	10647	0.6	1	10481 166
# 49	15175	0.6	1	14962 213
# 50	10529	0.6	1	10355 174
# 51	13040	0.6	1	12854 186
# 52	13130	0.6	1	12926 204
# 53	10634	0.6	1	10522 112
# 54	3407	0.6	1	3331 76
# 55	5481	0.6	1	5394 87
# 56	5889	0.6	1	5781 108
# 57	5408	0.6	1	5354 54
# 58	3734	0.6	1	3672 62
# 59	4156	0.6	1	4084 72
# 60	3257	0.6	1	3132 125
# 61	4769	0.6	1	4668 101
# 62	4125	0.6	1	4053 72
# 63	3023	0.6	1	2923 100
# 64	2888	0.6	1	2769 119
# 65	2389	0.6	1	2296 93
# 66	2504	0.6	1	2411 93
# 67	2593	0.6	1	2501 92
# 68	2374	0.6	1	2242 132
# 69	2330	0.6	1	2183 147
# 70	1899	0.6	1	1748 151
# 71	1545	0.6	1	1391 154
# 72	1524	0.6	1	1331 193
# 73	1920	0.6	1	1230 690
# 74	2339	0.6	1	2125 214
# 75	468	0.6	1	430 38
# 76	32	0.6	1	22 10
# 77	20	0.6	1	4 16
# 78	15	0.6	1	1 14
# 79	15	0.6	1	1 14
# 80	11	0.6	1	1 10
# 81	16	0.6	1	1 15
# 82	16	0.6	1	1 15
# 83	22	0.6	1	0 22
# 84	9	0.6	1	0 9
# 85	23	0.6	1	1 22
# 86	17	0.6	1	0 17
# 87	11	0.6	1	1 10
# 88	13	0.6	1	0 13
# 89	5	0.6	1	1 4
# 90	6	0.6	1	0 6
# 91	6	0.6	1	0 6
# 92	9	0.6	1	0 9
# 93	14	0.6	1	0 14
# 94	10	0.6	1	0 10
# 95	10	0.6	1	0 10
# 96	10	0.6	1	0 10
# 97	25	0.6	1	0 25
# 98	13	0.6	1	0 13
# 99	15	0.6	1	0 15
# 100	22	0.6	1	0 22
# 101	9	0.6	1	0 9
# 102	5	0.6	1	0 5
# 103	18	0.6	1	0 18
# 104	11	0.6	1	0 11
# 105	12	0.6	1	0 12
# 106	7	0.6	1	0 7
# 107	19	0.6	1	0 19
# 108	30	0.6	1	0 30
# 109	22	0.6	1	0 22
# 110	23	0.6	1	0 23
# 111	14	0.6	1	0 14
# 112	12	0.6	1	0 12
# 113	12	0.6	1	0 12
# 114	27	0.6	1	0 27
# 115	9	0.6	1	0 9
# 116	13	0.6	1	0 13
# 117	15	0.6	1	0 15
# 118	10	0.6	1	0 10
# 119	10	0.6	1	0 10
# 120	9	0.6	1	0 9
# 121	5	0.6	1	0 5
# 122	14	0.6	1	0 14
# 123	11	0.6	1	0 11
# 124	8	0.6	1	0 8
# 125	2	0.6	1	0 2
# 126	5	0.6	1	0 5
#
# RUN STATISTICS FOR INPUT FILE: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R1_001.fastq
# =============================================
# 41714643 sequences processed in total
# The length threshold of paired-end sequences gets evaluated later on (in the validation step)
#
# Writing report to '/DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/CC15N_CAGATC_L007_R2_001.fastq_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R2_001.fastq
# Trimming mode: paired-end
# Trim Galore version: 0.6.4_dev
# Cutadapt version: 3.4
# Number of cores used for trimming: 1
# Quality Phred score cutoff: 35
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length for both reads before a sequence pair gets removed: 20 bp
#
# Cutadapt seems to be fairly up-to-date (version 3.4). Setting -j -j 1
# Writing final adapter and quality trimmed output to CC15N_CAGATC_L007_R2_001_trimmed.fq
#
#
#   >>> Now performing quality (cutoff '-q 35') and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R2_001.fastq <<<
# 10000000 sequences processed
# 20000000 sequences processed
# 30000000 sequences processed
# 40000000 sequences processed
# This is cutadapt 3.4 with Python 3.8.5
# Command line parameters: -j 1 -e 0.1 -q 35 -O 1 -a AGATCGGAAGAGC /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R2_001.fastq
# Processing reads on 1 core in single-end mode ...
# Finished in 330.09 s (8 µs/read; 7.58 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              41,714,643
# Reads with adapters:                13,713,211 (32.9%)
# Reads written (passing filters):    41,714,643 (100.0%)
#
# Total basepairs processed: 5,256,045,018 bp
# Quality-trimmed:           1,524,635,140 bp (29.0%)
# Total written (filtered):  3,639,466,626 bp (69.2%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 13713211 times
#
# No. of allowed errors:
# 1-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
#   A: 29.1%
#   C: 30.8%
#   G: 25.6%
#   T: 14.4%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	6642236	10428660.8	0	6642236
# 2	1967698	2607165.2	0	1967698
# 3	719839	651791.3	0	719839
# 4	289362	162947.8	0	289362
# 5	202145	40737.0	0	202145
# 6	239281	10184.2	0	239281
# 7	236788	2546.1	0	236788
# 8	169917	636.5	0	169917
# 9	223130	159.1	0	222492 638
# 10	159114	39.8	1	157619 1495
# 11	118047	9.9	1	116619 1428
# 12	218160	2.5	1	216425 1735
# 13	119333	0.6	1	118065 1268
# 14	309766	0.6	1	307942 1824
# 15	54954	0.6	1	54261 693
# 16	89068	0.6	1	88161 907
# 17	213024	0.6	1	211689 1335
# 18	30376	0.6	1	29877 499
# 19	112455	0.6	1	111527 928
# 20	65248	0.6	1	64545 703
# 21	48426	0.6	1	47827 599
# 22	113452	0.6	1	112043 1409
# 23	128855	0.6	1	126849 2006
# 24	149593	0.6	1	147669 1924
# 25	46278	0.6	1	45611 667
# 26	82061	0.6	1	80912 1149
# 27	72980	0.6	1	72034 946
# 28	79871	0.6	1	78884 987
# 29	33631	0.6	1	32998 633
# 30	102233	0.6	1	101065 1168
# 31	23197	0.6	1	22778 419
# 32	51585	0.6	1	50824 761
# 33	44923	0.6	1	44165 758
# 34	58024	0.6	1	57224 800
# 35	40669	0.6	1	40107 562
# 36	32362	0.6	1	31912 450
# 37	54904	0.6	1	54171 733
# 38	26554	0.6	1	26119 435
# 39	36856	0.6	1	36430 426
# 40	25272	0.6	1	24931 341
# 41	35026	0.6	1	34480 546
# 42	39080	0.6	1	38598 482
# 43	11770	0.6	1	11559 211
# 44	23050	0.6	1	22725 325
# 45	28026	0.6	1	27691 335
# 46	11742	0.6	1	11576 166
# 47	8912	0.6	1	8757 155
# 48	11851	0.6	1	11706 145
# 49	8844	0.6	1	8683 161
# 50	9589	0.6	1	9413 176
# 51	14587	0.6	1	14419 168
# 52	4329	0.6	1	4240 89
# 53	4139	0.6	1	4071 68
# 54	5030	0.6	1	4955 75
# 55	6429	0.6	1	6326 103
# 56	4203	0.6	1	4126 77
# 57	5547	0.6	1	5440 107
# 58	5373	0.6	1	5283 90
# 59	4293	0.6	1	4212 81
# 60	4899	0.6	1	4783 116
# 61	4686	0.6	1	4574 112
# 62	4424	0.6	1	4300 124
# 63	4236	0.6	1	4051 185
# 64	3532	0.6	1	3383 149
# 65	3172	0.6	1	3048 124
# 66	3040	0.6	1	2854 186
# 67	3545	0.6	1	2738 807
# 68	6859	0.6	1	6704 155
# 69	131	0.6	1	107 24
# 70	14	0.6	1	0 14
# 71	18	0.6	1	0 18
# 72	22	0.6	1	1 21
# 73	22	0.6	1	1 21
# 74	34	0.6	1	1 33
# 75	22	0.6	1	1 21
# 76	21	0.6	1	2 19
# 77	11	0.6	1	1 10
# 78	25	0.6	1	3 22
# 79	21	0.6	1	3 18
# 80	31	0.6	1	3 28
# 81	12	0.6	1	0 12
# 82	32	0.6	1	2 30
# 83	20	0.6	1	2 18
# 84	15	0.6	1	0 15
# 85	18	0.6	1	0 18
# 86	13	0.6	1	1 12
# 87	19	0.6	1	0 19
# 88	19	0.6	1	0 19
# 89	13	0.6	1	0 13
# 90	19	0.6	1	2 17
# 91	22	0.6	1	0 22
# 92	21	0.6	1	0 21
# 93	16	0.6	1	0 16
# 94	32	0.6	1	0 32
# 95	34	0.6	1	0 34
# 96	19	0.6	1	0 19
# 97	23	0.6	1	1 22
# 98	16	0.6	1	0 16
# 99	31	0.6	1	0 31
# 100	24	0.6	1	0 24
# 101	22	0.6	1	0 22
# 102	36	0.6	1	0 36
# 103	25	0.6	1	0 25
# 104	37	0.6	1	0 37
# 105	23	0.6	1	1 22
# 106	34	0.6	1	0 34
# 107	23	0.6	1	1 22
# 108	12	0.6	1	0 12
# 109	17	0.6	1	1 16
# 110	16	0.6	1	0 16
# 111	14	0.6	1	1 13
# 112	17	0.6	1	0 17
# 113	20	0.6	1	0 20
# 114	19	0.6	1	0 19
# 115	13	0.6	1	0 13
# 116	12	0.6	1	0 12
# 117	19	0.6	1	2 17
# 118	18	0.6	1	0 18
# 119	17	0.6	1	0 17
# 120	11	0.6	1	0 11
# 121	19	0.6	1	0 19
# 122	13	0.6	1	1 12
# 123	43	0.6	1	0 43
# 124	19	0.6	1	0 19
# 125	30	0.6	1	0 30
# 126	12	0.6	1	0 12
#
# RUN STATISTICS FOR INPUT FILE: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC15N_CAGATC_L007_R2_001.fastq
# =============================================
# 41714643 sequences processed in total
# The length threshold of paired-end sequences gets evaluated later on (in the validation step)
#
# Validate paired-end files CC15N_CAGATC_L007_R1_001_trimmed.fq and CC15N_CAGATC_L007_R2_001_trimmed.fq
# file_1: CC15N_CAGATC_L007_R1_001_trimmed.fq, file_2: CC15N_CAGATC_L007_R2_001_trimmed.fq
#
#
# >>>>> Now validing the length of the 2 paired-end infiles: CC15N_CAGATC_L007_R1_001_trimmed.fq and CC15N_CAGATC_L007_R2_001_trimmed.fq <<<<<
# Writing validated paired-end Read 1 reads to CC15N_CAGATC_L007_R1_001_val_1.fq
# Writing validated paired-end Read 2 reads to CC15N_CAGATC_L007_R2_001_val_2.fq
# Total number of sequences analysed: 41714643
#
# Number of sequence pairs removed because at least one read was shorter than the length cutoff (20 bp): 12692405 (30.43%)
#
# Deleting both intermediate output files CC15N_CAGATC_L007_R1_001_trimmed.fq and CC15N_CAGATC_L007_R2_001_trimmed.fq
#
# ====================================================================================================
#
# CC17N_CGATGT_L008
# CC17N_CGATGT_L008_R1_001.fastq
# CC17N_CGATGT_L008_R2_001.fastq
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R1_001.fastq
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 3.4
# single-core operation.
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R1_001.fastq <<)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	165086	AGATCGGAAGAGC	1000000	16.51
# Nextera	18	CTGTCTCTTATA	1000000	0.00
# smallRNA	8	TGGAATTCTCGG	1000000	0.00
# Using Illumina adapter for trimming (count: 165086). Second best hit was Nextera (count: 18)
#
# Writing report to '/DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/CC17N_CGATGT_L008_R1_001.fastq_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R1_001.fastq
# Trimming mode: paired-end
# Trim Galore version: 0.6.4_dev
# Cutadapt version: 3.4
# Number of cores used for trimming: 1
# Quality Phred score cutoff: 35
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length for both reads before a sequence pair gets removed: 20 bp
#
# Cutadapt seems to be fairly up-to-date (version 3.4). Setting -j 1
# Writing final adapter and quality trimmed output to CC17N_CGATGT_L008_R1_001_trimmed.fq
#
#
#   >>> Now performing quality (cutoff '-q 35') and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R1_001.fastq <<<
# 10000000 sequences processed
# 20000000 sequences processed
# 30000000 sequences processed
# This is cutadapt 3.4 with Python 3.8.5
# Command line parameters: -j 1 -e 0.1 -q 35 -O 1 -a AGATCGGAAGAGC /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R1_001.fastq
# Processing reads on 1 core in single-end mode ...
# Finished in 319.84 s (8 µs/read; 7.18 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              38,296,076
# Reads with adapters:                16,108,083 (42.1%)
# Reads written (passing filters):    38,296,076 (100.0%)
#
# Total basepairs processed: 4,825,305,576 bp
# Quality-trimmed:             993,932,392 bp (20.6%)
# Total written (filtered):  3,667,319,992 bp (76.0%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 16108083 times
#
# No. of allowed errors:
# 1-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
#   A: 27.8%
#   C: 29.1%
#   G: 26.3%
#   T: 16.8%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	6297864	9574019.0	0	6297864
# 2	2064341	2393504.8	0	2064341
# 3	692424	598376.2	0	692424
# 4	348027	149594.0	0	348027
# 5	227983	37398.5	0	227983
# 6	287685	9349.6	0	287685
# 7	291180	2337.4	0	291180
# 8	211555	584.4	0	211555
# 9	262533	146.1	0	262187 346
# 10	184770	36.5	1	182913 1857
# 11	170479	9.1	1	168731 1748
# 12	216714	2.3	1	214523 2191
# 13	192457	0.6	1	190505 1952
# 14	213783	0.6	1	211255 2528
# 15	188645	0.6	1	186300 2345
# 16	206188	0.6	1	203366 2822
# 17	243733	0.6	1	240668 3065
# 18	152414	0.6	1	150500 1914
# 19	188402	0.6	1	186069 2333
# 20	148462	0.6	1	146387 2075
# 21	242381	0.6	1	238886 3495
# 22	166694	0.6	1	164419 2275
# 23	148593	0.6	1	146479 2114
# 24	190989	0.6	1	188344 2645
# 25	139620	0.6	1	137618 2002
# 26	134925	0.6	1	133072 1853
# 27	152265	0.6	1	149914 2351
# 28	170549	0.6	1	168012 2537
# 29	149509	0.6	1	147346 2163
# 30	116146	0.6	1	114476 1670
# 31	117141	0.6	1	115438 1703
# 32	119104	0.6	1	117199 1905
# 33	122792	0.6	1	120689 2103
# 34	127582	0.6	1	125316 2266
# 35	141442	0.6	1	138432 3010
# 36	152599	0.6	1	150388 2211
# 37	94005	0.6	1	92817 1188
# 38	37388	0.6	1	36534 854
# 39	80932	0.6	1	79657 1275
# 40	61176	0.6	1	58055 3121
# 41	161016	0.6	1	159632 1384
# 42	10412	0.6	1	10178 234
# 43	6770	0.6	1	6669 101
# 44	14584	0.6	1	14397 187
# 45	29260	0.6	1	28971 289
# 46	34365	0.6	1	33978 387
# 47	44421	0.6	1	43973 448
# 48	24623	0.6	1	24317 306
# 49	38908	0.6	1	38429 479
# 50	27439	0.6	1	27065 374
# 51	32453	0.6	1	32006 447
# 52	34011	0.6	1	33367 644
# 53	29886	0.6	1	29489 397
# 54	8435	0.6	1	8176 259
# 55	14892	0.6	1	14557 335
# 56	15664	0.6	1	15345 319
# 57	14889	0.6	1	14603 286
# 58	9429	0.6	1	9235 194
# 59	11032	0.6	1	10779 253
# 60	8773	0.6	1	8260 513
# 61	11321	0.6	1	10851 470
# 62	9474	0.6	1	9249 225
# 63	7555	0.6	1	7023 532
# 64	6168	0.6	1	5648 520
# 65	4921	0.6	1	4536 385
# 66	5162	0.6	1	4663 499
# 67	4882	0.6	1	4333 549
# 68	4653	0.6	1	3890 763
# 69	4273	0.6	1	3357 916
# 70	3736	0.6	1	2706 1030
# 71	3273	0.6	1	2206 1067
# 72	3091	0.6	1	1779 1312
# 73	8245	0.6	1	1530 6715
# 74	3486	0.6	1	2113 1373
# 75	544	0.6	1	456 88
# 76	26	0.6	1	12 14
# 77	8	0.6	1	1 7
# 78	14	0.6	1	1 13
# 79	6	0.6	1	1 5
# 80	8	0.6	1	1 7
# 81	8	0.6	1	0 8
# 82	8	0.6	1	0 8
# 83	11	0.6	1	0 11
# 84	8	0.6	1	0 8
# 85	15	0.6	1	0 15
# 86	12	0.6	1	0 12
# 87	4	0.6	1	0 4
# 88	13	0.6	1	0 13
# 89	7	0.6	1	0 7
# 90	6	0.6	1	0 6
# 91	7	0.6	1	0 7
# 92	6	0.6	1	0 6
# 93	8	0.6	1	0 8
# 94	8	0.6	1	0 8
# 95	13	0.6	1	0 13
# 96	14	0.6	1	0 14
# 97	10	0.6	1	0 10
# 98	10	0.6	1	0 10
# 99	11	0.6	1	0 11
# 100	19	0.6	1	0 19
# 101	5	0.6	1	0 5
# 102	8	0.6	1	0 8
# 103	15	0.6	1	0 15
# 104	7	0.6	1	0 7
# 105	4	0.6	1	0 4
# 106	11	0.6	1	0 11
# 107	16	0.6	1	0 16
# 108	12	0.6	1	0 12
# 109	13	0.6	1	0 13
# 110	13	0.6	1	0 13
# 111	20	0.6	1	0 20
# 112	14	0.6	1	0 14
# 113	21	0.6	1	0 21
# 114	20	0.6	1	0 20
# 115	16	0.6	1	0 16
# 116	9	0.6	1	0 9
# 117	12	0.6	1	0 12
# 118	3	0.6	1	0 3
# 119	3	0.6	1	0 3
# 120	7	0.6	1	0 7
# 121	6	0.6	1	0 6
# 122	6	0.6	1	0 6
# 123	19	0.6	1	1 18
# 124	7	0.6	1	0 7
# 125	11	0.6	1	0 11
# 126	28	0.6	1	0 28
#
# RUN STATISTICS FOR INPUT FILE: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R1_001.fastq
# =============================================
# 38296076 sequences processed in total
# The length threshold of paired-end sequences gets evaluated later on (in the validation step)
#
# Writing report to '/DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/CC17N_CGATGT_L008_R2_001.fastq_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R2_001.fastq
# Trimming mode: paired-end
# Trim Galore version: 0.6.4_dev
# Cutadapt version: 3.4
# Number of cores used for trimming: 1
# Quality Phred score cutoff: 35
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length for both reads before a sequence pair gets removed: 20 bp
#
# Cutadapt seems to be fairly up-to-date (version 3.4). Setting -j -j 1
# Writing final adapter and quality trimmed output to CC17N_CGATGT_L008_R2_001_trimmed.fq
#
#
#   >>> Now performing quality (cutoff '-q 35') and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R2_001.fastq <<<
# 10000000 sequences processed
# 20000000 sequences processed
# 30000000 sequences processed
# This is cutadapt 3.4 with Python 3.8.5
# Command line parameters: -j 1 -e 0.1 -q 35 -O 1 -a AGATCGGAAGAGC /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R2_001.fastq
# Processing reads on 1 core in single-end mode ...
# Finished in 318.33 s (8 µs/read; 7.22 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              38,296,076
# Reads with adapters:                15,400,848 (40.2%)
# Reads written (passing filters):    38,296,076 (100.0%)
#
# Total basepairs processed: 4,825,305,576 bp
# Quality-trimmed:           1,114,608,929 bp (23.1%)
# Total written (filtered):  3,564,882,738 bp (73.9%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 15400848 times
#
# No. of allowed errors:
# 1-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
#   A: 28.5%
#   C: 31.2%
#   G: 26.4%
#   T: 14.0%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	6469309	9574019.0	0	6469309
# 2	1748216	2393504.8	0	1748216
# 3	757920	598376.2	0	757920
# 4	319631	149594.0	0	319631
# 5	243022	37398.5	0	243022
# 6	290513	9349.6	0	290513
# 7	284544	2337.4	0	284544
# 8	218363	584.4	0	218363
# 9	291122	146.1	0	290493 629
# 10	192810	36.5	1	191126 1684
# 11	162536	9.1	1	160822 1714
# 12	276078	2.3	1	274076 2002
# 13	159690	0.6	1	157841 1849
# 14	406821	0.6	1	404368 2453
# 15	75667	0.6	1	74784 883
# 16	128842	0.6	1	127548 1294
# 17	299466	0.6	1	297781 1685
# 18	45523	0.6	1	44792 731
# 19	162052	0.6	1	160925 1127
# 20	96365	0.6	1	95588 777
# 21	78451	0.6	1	77811 640
# 22	160719	0.6	1	159231 1488
# 23	183216	0.6	1	181101 2115
# 24	217173	0.6	1	214904 2269
# 25	78614	0.6	1	77742 872
# 26	130770	0.6	1	129317 1453
# 27	123178	0.6	1	121683 1495
# 28	130013	0.6	1	128825 1188
# 29	61263	0.6	1	60380 883
# 30	176345	0.6	1	174697 1648
# 31	41360	0.6	1	40895 465
# 32	90622	0.6	1	89704 918
# 33	79800	0.6	1	78899 901
# 34	111107	0.6	1	109963 1144
# 35	72932	0.6	1	72089 843
# 36	63885	0.6	1	63084 801
# 37	107320	0.6	1	106199 1121
# 38	56574	0.6	1	55881 693
# 39	73472	0.6	1	72671 801
# 40	54338	0.6	1	53623 715
# 41	75043	0.6	1	74074 969
# 42	91002	0.6	1	90100 902
# 43	24504	0.6	1	24088 416
# 44	53317	0.6	1	52352 965
# 45	68549	0.6	1	67718 831
# 46	28954	0.6	1	28570 384
# 47	23743	0.6	1	23347 396
# 48	30298	0.6	1	29962 336
# 49	24303	0.6	1	23959 344
# 50	25888	0.6	1	25278 610
# 51	41374	0.6	1	40951 423
# 52	11181	0.6	1	10983 198
# 53	11865	0.6	1	11696 169
# 54	12490	0.6	1	12273 217
# 55	17935	0.6	1	17626 309
# 56	11382	0.6	1	11139 243
# 57	14699	0.6	1	14363 336
# 58	14017	0.6	1	13655 362
# 59	10990	0.6	1	10685 305
# 60	12205	0.6	1	11873 332
# 61	11431	0.6	1	11062 369
# 62	10676	0.6	1	10027 649
# 63	9892	0.6	1	9367 525
# 64	7950	0.6	1	7293 657
# 65	7034	0.6	1	6206 828
# 66	6463	0.6	1	5262 1201
# 67	12840	0.6	1	4647 8193
# 68	9776	0.6	1	9489 287
# 69	241	0.6	1	201 40
# 70	27	0.6	1	14 13
# 71	23	0.6	1	1 22
# 72	21	0.6	1	4 17
# 73	12	0.6	1	1 11
# 74	28	0.6	1	3 25
# 75	27	0.6	1	0 27
# 76	15	0.6	1	0 15
# 77	22	0.6	1	0 22
# 78	26	0.6	1	1 25
# 79	26	0.6	1	0 26
# 80	36	0.6	1	1 35
# 81	16	0.6	1	1 15
# 82	19	0.6	1	2 17
# 83	14	0.6	1	0 14
# 84	17	0.6	1	0 17
# 85	14	0.6	1	1 13
# 86	19	0.6	1	0 19
# 87	19	0.6	1	1 18
# 88	11	0.6	1	0 11
# 89	16	0.6	1	0 16
# 90	10	0.6	1	0 10
# 91	12	0.6	1	0 12
# 92	15	0.6	1	1 14
# 93	20	0.6	1	0 20
# 94	34	0.6	1	0 34
# 95	25	0.6	1	0 25
# 96	14	0.6	1	0 14
# 97	21	0.6	1	0 21
# 98	21	0.6	1	0 21
# 99	23	0.6	1	0 23
# 100	23	0.6	1	0 23
# 101	13	0.6	1	0 13
# 102	22	0.6	1	0 22
# 103	15	0.6	1	0 15
# 104	29	0.6	1	0 29
# 105	11	0.6	1	0 11
# 106	38	0.6	1	1 37
# 107	17	0.6	1	0 17
# 108	16	0.6	1	0 16
# 109	17	0.6	1	0 17
# 110	6	0.6	1	0 6
# 111	21	0.6	1	0 21
# 112	14	0.6	1	0 14
# 113	15	0.6	1	0 15
# 114	14	0.6	1	0 14
# 115	13	0.6	1	0 13
# 116	7	0.6	1	0 7
# 117	22	0.6	1	0 22
# 118	22	0.6	1	0 22
# 119	15	0.6	1	0 15
# 120	7	0.6	1	1 6
# 121	13	0.6	1	1 12
# 122	20	0.6	1	0 20
# 123	30	0.6	1	0 30
# 124	20	0.6	1	0 20
# 125	36	0.6	1	0 36
# 126	85	0.6	1	1 84
#
# RUN STATISTICS FOR INPUT FILE: /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/CC17N_CGATGT_L008_R2_001.fastq
# =============================================
# 38296076 sequences processed in total
# The length threshold of paired-end sequences gets evaluated later on (in the validation step)
#
# Validate paired-end files CC17N_CGATGT_L008_R1_001_trimmed.fq and CC17N_CGATGT_L008_R2_001_trimmed.fq
# file_1: CC17N_CGATGT_L008_R1_001_trimmed.fq, file_2: CC17N_CGATGT_L008_R2_001_trimmed.fq
#
#
# >>>>> Now validing the length of the 2 paired-end infiles: CC17N_CGATGT_L008_R1_001_trimmed.fq and CC17N_CGATGT_L008_R2_001_trimmed.fq <<<<<
# Writing validated paired-end Read 1 reads to CC17N_CGATGT_L008_R1_001_val_1.fq
# Writing validated paired-end Read 2 reads to CC17N_CGATGT_L008_R2_001_val_2.fq
#
# Total number of sequences analysed: 38296076
#
# Number of sequence pairs removed because at least one read was shorter than the length cutoff (20 bp): 8930126 (23.32%)
#
# Deleting both intermediate output files CC17N_CGATGT_L008_R1_001_trimmed.fq and CC17N_CGATGT_L008_R2_001_trimmed.fq
#
# ====================================================================================================

# %% [markdown]
# ### Run the aligner (STAR)
# In this case is a small script to run STAR with paired-end files
# Be aware of the path to the directory to change for the new one

# %%
# Variables to know where are the binary, references DO NOT CHANGE them
STAR_BINARY="/home/l.gonzalez/programs/STAR-2.7.5c/bin/Linux_x86_64_static/STAR"
GENE_REFERENCE="/DATA/share/pipelines/lgleon/References/Ensembl/STAR_Ref/Homo_sapiens.GRCh38.99.gtf"
STAR_INDEX="//DATA/share/pipelines/lgleon/References/Ensembl/newSTAR_idx"
USE_THREADS=16

#those ones you need to change with each analysis (run), here and in the script before run it
WORKING_DIR = "/DATA/share/pipelines/lgleon/C5_RNAseq_FFPE/"
DIR_INPUT_SAMPLES = "/DATA/share/pipelines/lgleon/C5_RNAseq_FFPE/fastq_files"
DIR_BAM_OUTPUT = "/DATA/share/pipelines/lgleon/C5_RNAseq_FFPE/bam_test_notrimm/"

# %%
# The idea is run directly the small bash script /home/l.gonzalez/Notebooks/run_newpairedSTAR.sh
# OR  /home/l.gonzalez/Notebooks/run_STAR_singleORpaired.sh
# what is in this scrript: DO NOT RUN IT, IT WILL NOT WORK LIKE THAT

#script:

#!bin/bash

#############################################################################
##############################################################################
# SINGLE-END part
##############################################################################
##############################################################################


#where are the data that we are analyzing, this part is hard code need to be change each time
prj=/DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/test-code

#loop to interact over all the fastq files in the folder, take one file
#check the nale-tail of the files and adapt if need it
for i in ${prj}/*R1*.f*q.gz 

do 
    name=$(basename ${i} _R1_001.fastq.gz) 

	echo ${name}
	echo ${name}_R1_001.fastq.gz
#	echo ${name}_R2_001.fastq.gz
	echo ${prj}/output/


    /home/l.gonzalez/programs/STAR-2.7.5c/bin/Linux_x86_64_static/STAR \
    --runMode alignReads \
    --genomeDir /DATA/share/pipelines/lgleon/References/Ensembl/newSTAR_idx/ \
    --runThreadN 16 \
    --sjdbGTFfile /DATA/share/pipelines/lgleon/References/Ensembl/STAR_Ref/Homo_sapiens.GRCh38.99.gtf \
    --readFilesIn  ${name}_R1_001.fastq.gz \
    --outSAMtype BAM SortedByCoordinate \
    --outFileNamePrefix ${prj}/output/ \
    --outFilterMismatchNmax 10 \
    --outFilterIntronMotifs None \
    --chimSegmentMin 1 \
    --sjdbScore 2 \
    --quantMode GeneCounts \
    --readFilesCommand zcat


done

# you can convert this one in parired end, 
# simple removing the # from the R2 and adding the second fastq in the input

# %% [markdown]
# ### To modified the file here, just open the sh file and do it, easy peasy
# We are in /home/l.gonzalez/Notebooks

# %%
## Alignment with STAR
## Go to the folder where you wanto to save the results
## Once you changed the proj folder, run this cell

#!bash /home/l.gonzalez/Notebooks/run_newpairedSTAR.sh 
#!bash /home/l.gonzalez/Notebooks/run_STAR_singleORpaired.sh

#testing code 
#!bash /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/test-code/test_newpairedSTAR.sh
# !bash /home/l.gonzalez/Notebooks/run_newpairedSTAR.sh
# Out:
# CC15N_CAGATC_L007
# CC15N_CAGATC_L007_R1_001_val_1.fq
# CC15N_CAGATC_L007_R2_001_val_2.fq
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/CC15N_CAGATC_L007_R1_001_val_1.fq
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/output/
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/output/CC15N_CAGATC_L007
# Jun 23 08:46:26 ..... started STAR run
# Jun 23 08:46:26 ..... loading genome
# Jun 23 08:46:44 ..... processing annotations GTF
# Jun 23 08:46:57 ..... inserting junctions into the genome indices
# Jun 23 08:48:25 ..... started mapping
# Jun 23 08:51:58 ..... finished mapping
# Jun 23 08:52:01 ..... started sorting BAM
# Jun 23 08:53:16 ..... finished successfully
# CC17N_CGATGT_L008
# CC17N_CGATGT_L008_R1_001_val_1.fq
# CC17N_CGATGT_L008_R2_001_val_2.fq
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/CC17N_CGATGT_L008_R1_001_val_1.fq
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/output/
# /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/fastq_normals/trimmNormals/output/CC17N_CGATGT_L008
# Jun 23 08:53:20 ..... started STAR run
# Jun 23 08:53:20 ..... loading genome
# Jun 23 08:53:38 ..... processing annotations GTF
# Jun 23 08:53:51 ..... inserting junctions into the genome indices
# Jun 23 08:55:20 ..... started mapping
# Jun 23 08:58:50 ..... finished mapping
# Jun 23 08:58:53 ..... started sorting BAM
# Jun 23 08:59:45 ..... finished successfully

# %% [markdown]
# ### Run featureCounts
# Again it is just a line in CLI, so go where you have the bam files and run it from there

# %%
## To run featureCounts is also a line that we can call frem here
## go to the folder where all the bam files are store after algnment 
## Be aware:
Binary = "/home/l.gonzalez/programs/subread-2.0.1-source/bin/featureCounts"
GFT_Ref = "/DATA/share/pipelines/lgleon/References/gencoderef/hg19/gencode.v19.annotation.gtf"

## run
# !/home/l.gonzalez/programs/subread-2.0.1-source/bin/featureCounts \
-T 16 -t gene -g gene_name -O -s 0 -M -Q 10 -a \
/DATA/share/pipelines/lgleon/References/Ensembl/STAR_Ref/Homo_sapiens.GRCh38.99.gtf -F GTF/GFF \
-o /DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/counts/fcounts_hg38_genename.counts \
/DATA/share/pipelines/lgleon/organoids_rawdata/RNAseq/bam_star/*bam

#!/home/l.gonzalez/programs/subread-2.0.1-source/bin/featureCounts \
#-T 16 -t exon -g exon_id -O -s 0 -M -Q 10 -a \
#DATA/share/pipelines/lgleon/References/Ensembl/STAR_Ref/Homo_sapiens.GRCh38.99.gtf -F GTF/GFF \
#-o /DATA/share/pipelines/lgleon/NGS_protocol/RNA_Seq/Processed_Data/counts/NGS_normal_exon.counts \
#/DATA/share/pipelines/lgleon/NGS_protocol/RNA_Seq/Processed_Data/complete/Bam_normal_adjcentColon/*bam

#Feature type(-t), 3rd column GTF file
#CDS
#Selenocysteine
#exon
#five_prime_utr
#gene
#start_codon
#stop_codon
#three_prime_utr
#transcript

#Atrivute that can be use (-g):
#An example of attributes included in your GTF annotation is:
#'gene_id "ENSG00000223972"; 
#gene_version "5"; 
#transcript_id "ENST00000456328"; 
#transcript_version "2"; 
#exon_number "1"; 
#gene_name "DDX11L1"; 
#gene_source "havana"; 
#gene_biotype "transcribed_unprocessed_pseudogene"; 
#transcript_name "DDX11L1-202"; 
#transcript_source "havana"; 
#transcript_biotype "processed_transcript"; 
#exon_id "ENSE00002234944"; 
#exon_version "1"; 
#tag "basic"; 
#transcript_support_level "1";'
# Out:
# Warning: Unknown annotation format: GTF/GFF. GTF format is used.
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 18 BAM files                                     ||
# ||                           o B16PON-C-002-A_S1Aligned.sortedByCoord.out ... ||
# ||                           o B16PON-C-003-A_S2Aligned.sortedByCoord.out ... ||
# ||                           o B16PON-C-004-A_S3Aligned.sortedByCoord.out ... ||
# ||                           o B16PON-C-006_S4Aligned.sortedByCoord.out.bam   ||
# ||                           o B16PON-C-008_S5Aligned.sortedByCoord.out.bam   ||
# ||                           o B16PON-C-009_S6Aligned.sortedByCoord.out.bam   ||
# ||                           o B16PON-C-015_S7Aligned.sortedByCoord.out.bam   ||
# ||                           o B16PON-C-017_S8Aligned.sortedByCoord.out.bam   ||
# ||                           o B16PON-C-020_S9Aligned.sortedByCoord.out.bam   ||
# ||                           o B16PON-C-027_S10Aligned.sortedByCoord.out.bam  ||
# ||                           o B16PON-C-036_S21Aligned.sortedByCoord.out.bam  ||
# ||                           o B16PON-C-040_S22Aligned.sortedByCoord.out.bam  ||
# ||                           o B16PON-C-041_S11Aligned.sortedByCoord.out.bam  ||
# ||                           o B16PON-C-045_S23Aligned.sortedByCoord.out.bam  ||
# ||                           o B16PON-C-046_S12Aligned.sortedByCoord.out.bam  ||
# ||                           o B16PON-C-047_S13Aligned.sortedByCoord.out.bam  ||
# ||                           o B16PON-C-048_S24Aligned.sortedByCoord.out.bam  ||
# ||                           o B16PON-C-049_S14Aligned.sortedByCoord.out.bam  ||
# ||                                                                            ||
# ||             Output file : fcounts_hg38_genename.counts                     ||
# ||                 Summary : fcounts_hg38_genename.counts.summary             ||
# ||              Annotation : Homo_sapiens.GRCh38.99.gtf (GTF)                 ||
# ||      Dir for temp files : /DATA/share/pipelines/lgleon/organoids_rawda ... ||
# ||                                                                            ||
# ||                 Threads : 16                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : counted                                          ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file Homo_sapiens.GRCh38.99.gtf ...                        ||
# ||    Features : 60676                                                        ||
# ||    Meta-features : 60642                                                   ||
# ||    Chromosomes/contigs : 47                                                ||
# ||                                                                            ||
# || Process BAM file B16PON-C-002-A_S1Aligned.sortedByCoord.out.bam...         ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 55625758                                             ||
# ||    Successfully assigned alignments : 46537824 (83.7%)                     ||
# ||    Running time : 0.09 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-003-A_S2Aligned.sortedByCoord.out.bam...         ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 53106538                                             ||
# ||    Successfully assigned alignments : 43785580 (82.4%)                     ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-004-A_S3Aligned.sortedByCoord.out.bam...         ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 52261896                                             ||
# ||    Successfully assigned alignments : 43044474 (82.4%)                     ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-006_S4Aligned.sortedByCoord.out.bam...           ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 103282045                                            ||
# ||    Successfully assigned alignments : 37208720 (36.0%)                     ||
# ||    Running time : 0.15 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-008_S5Aligned.sortedByCoord.out.bam...           ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 55006036                                             ||
# ||    Successfully assigned alignments : 45639579 (83.0%)                     ||
# ||    Running time : 0.09 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-009_S6Aligned.sortedByCoord.out.bam...           ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 50074880                                             ||
# ||    Successfully assigned alignments : 41761024 (83.4%)                     ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-015_S7Aligned.sortedByCoord.out.bam...           ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 49072196                                             ||
# ||    Successfully assigned alignments : 42051946 (85.7%)                     ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-017_S8Aligned.sortedByCoord.out.bam...           ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 47922223                                             ||
# ||    Successfully assigned alignments : 39965068 (83.4%)                     ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-020_S9Aligned.sortedByCoord.out.bam...           ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 62655466                                             ||
# ||    Successfully assigned alignments : 52619003 (84.0%)                     ||
# ||    Running time : 0.10 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-027_S10Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 59420369                                             ||
# ||    Successfully assigned alignments : 50257247 (84.6%)                     ||
# ||    Running time : 0.10 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-036_S21Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 54347595                                             ||
# ||    Successfully assigned alignments : 44925977 (82.7%)                     ||
# ||    Running time : 0.09 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-040_S22Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 56344219                                             ||
# ||    Successfully assigned alignments : 47700132 (84.7%)                     ||
# ||    Running time : 0.10 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-041_S11Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 53251989                                             ||
# ||    Successfully assigned alignments : 44880162 (84.3%)                     ||
# ||    Running time : 0.09 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-045_S23Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 61192937                                             ||
# ||    Successfully assigned alignments : 52360705 (85.6%)                     ||
# ||    Running time : 0.11 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-046_S12Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 78773066                                             ||
# ||    Successfully assigned alignments : 66491600 (84.4%)                     ||
# ||    Running time : 0.12 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-047_S13Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 48246269                                             ||
# ||    Successfully assigned alignments : 40694377 (84.3%)                     ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-048_S24Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 70816151                                             ||
# ||    Successfully assigned alignments : 58708845 (82.9%)                     ||
# ||    Running time : 0.14 minutes                                             ||
# ||                                                                            ||
# || Process BAM file B16PON-C-049_S14Aligned.sortedByCoord.out.bam...          ||
# ||    WARNING: Paired-end reads were found.                                   ||
# ||    Total alignments : 65671411                                             ||
# ||    Successfully assigned alignments : 54879882 (83.6%)                     ||
# ||    Running time : 0.10 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "/DATA/share/pipelines/l  ||
# || gleon/organoids_rawdata/RNAseq/counts/fcounts_hg38_genename.counts.summar  ||
# || y"                                                                         ||
# ||                                                                            ||
# \\============================================================================//

# %% [markdown]
# ### After the analysis we will check the QC of the steps that we ran
# To do that, please go to the cell below and change the path to the folders where the fastqc files are, also the bam/bai files and multiqc will create a html with all the files

# %%
# !multiqc /DATA/share/pipelines/lgleon/test/testCode_steps_Nousefuldata/testdata/fastq/

# %%
#for fname in glob.glob(DIR_INPUT_SAMPLES + "/*.f*q.gz"):
#    print(fname)
